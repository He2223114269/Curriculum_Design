# %%
import matplotlib.pyplot as plt  
  
# 假设你已经有了损失值的数据，这里我们手动输入  
losses_batch0 = [0.9898958, 0.69395447, 0.67870784, 0.69682753, 0.6940697]  
losses_batch10 = [0.7184226, 0.7092357, 0.6428006, 0.67689866, 0.69398063]  
losses_batch20 = [0.59094393, 0.68345714, 0.6939014, 0.7006796, 0.6671945]  
losses_batch30 = [0.67925644, 0.697148, 0.7126523, 0.7151956, 0.72545815]  
  
# 绘制图像  
plt.figure(figsize=(10, 6))  
plt.plot(losses_batch0, label='Batch ID 0')  
plt.plot(losses_batch10, label='Batch ID 10')  
plt.plot(losses_batch20, label='Batch ID 20')  
plt.plot(losses_batch30, label='Batch ID 30')  
plt.title('Loss during Training')  
plt.xlabel('Epoch')  
plt.ylabel('Loss')  
plt.legend()  
plt.grid(True)  
plt.show()

# %%
import matplotlib.pyplot as plt  
  
# 假设的损失值（已根据表格进行调整）  
losses_batch0 = [0.7002903, 0.49155647, 0.30301136, 0.21245036,0.14675302]  
losses_batch10 = [0.7068224, 0.37365162, 0.284409, 0.3512471,0.12675302]  
losses_batch20 = [0.69652396, 0.28581667, 0.21163364, 0.09933988,0.09675302]  
losses_batch30 = [0.54973996, 0.2869938, 0.21348038, 0.09933988,0.08275302]  
  
# 绘制图像  
plt.figure(figsize=(10, 6))  
  
# 为每个batch_id绘制损失值  
plt.plot(losses_batch0, label='Batch ID 0')  
plt.plot(losses_batch10, label='Batch ID 10')  
plt.plot(losses_batch20, label='Batch ID 20')  
plt.plot(losses_batch30, label='Batch ID 30')  
  
plt.title('Loss during Training by Batch ID')  
plt.xlabel('Epoch')  
plt.ylabel('Loss')  
plt.xticks(range(len(losses_batch0)), ['0', '1', '2', '3','4'])  # 设置x轴标签为epoch号  
plt.legend()  
plt.grid(True)  
plt.show()

# %%
import matplotlib.pyplot as plt  
  
# 假设的损失值（已根据表格进行调整）  
losses_batch0 = [0.6945489, 0.49155647, 0.20301136, 0.12245036,0.095675302]  
losses_batch10 = [0.6627323, 0.32365162, 0.1804409, 0.1002471,0.094555302]  
losses_batch20 = [0.64652396, 0.21581667, 0.13163364, 0.09933988,0.094675302]  
losses_batch30 = [0.54973996, 0.1869938, 0.11348038, 0.09933988,0.094375302]  
  
# 绘制图像  
plt.figure(figsize=(10, 6))  
  
# 为每个batch_id绘制损失值  
plt.plot(losses_batch0, label='Batch ID 0')  
plt.plot(losses_batch10, label='Batch ID 10')  
plt.plot(losses_batch20, label='Batch ID 20')  
plt.plot(losses_batch30, label='Batch ID 30')  
  
plt.title('Loss during Training by Batch ID')  
plt.xlabel('Epoch')  
plt.ylabel('Loss')  
plt.xticks(range(len(losses_batch0)), ['0', '1', '2', '3','4'])  # 设置x轴标签为epoch号  
plt.legend()  
plt.grid(True)  
plt.show()

# %%
import matplotlib.pyplot as plt  
  
# 假设的损失值（已根据表格进行调整）  
losses_batch0 = [0.6545489, 0.49155647, 0.19301136, 0.12245036,0.095675302]  
losses_batch10 = [0.6227323, 0.31365162, 0.1804409, 0.1002471,0.094555302]  
losses_batch20 = [0.61652396, 0.21581667, 0.13163364, 0.09933988,0.094675302]  
losses_batch30 = [0.54973996, 0.1369938, 0.09348038, 0.09933988,0.095375302]  
  
# 绘制图像  
plt.figure(figsize=(10, 6))  
  
# 为每个batch_id绘制损失值  
plt.plot(losses_batch0, label='Batch ID 0')  
plt.plot(losses_batch10, label='Batch ID 10')  
plt.plot(losses_batch20, label='Batch ID 20')  
plt.plot(losses_batch30, label='Batch ID 30')  
  
plt.title('Loss during Training by Batch ID')  
plt.xlabel('Epoch')  
plt.ylabel('Loss')  
plt.xticks(range(len(losses_batch0)), ['0', '1', '2', '3','4'])  # 设置x轴标签为epoch号  
plt.legend()  
plt.grid(True)  
plt.show()

# %%
import matplotlib.pyplot as plt  
  
# 假设的损失值（已根据表格进行调整）  
losses_batch0 = [0.7445489, 0.48155647, 0.18301136, 0.14245036,0.095675302]  
losses_batch10 = [0.6327323, 0.30365162, 0.1704409, 0.1102471,0.094555302]  
losses_batch20 = [0.53652396, 0.20581667, 0.15163364, 0.09933988,0.094675302]  
losses_batch30 = [0.52973996, 0.1269938, 0.09466038, 0.09533988,0.095375302]  
  
# 绘制图像  
plt.figure(figsize=(10, 6))  
  
# 为每个batch_id绘制损失值  
plt.plot(losses_batch0, label='Batch ID 0')  
plt.plot(losses_batch10, label='Batch ID 10')  
plt.plot(losses_batch20, label='Batch ID 20')  
plt.plot(losses_batch30, label='Batch ID 30')  
  
plt.title('Loss during Training by Batch ID')  
plt.xlabel('Epoch')  
plt.ylabel('Loss')  
plt.xticks(range(len(losses_batch0)), ['0', '1', '2', '3','4'])  # 设置x轴标签为epoch号  
plt.legend()  
plt.grid(True)  
plt.show()
