# %% [markdown]
# 共线性研究

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

data = pd.read_excel("能源结构.xlsx")
data
# Out:
#      地区    年份      产业结构   城镇化率  二氧化硫排放强度     劳动力升级    煤炭消费占比      能源效率  \
# 0    上海  2010  0.570061  89.30  0.001366  0.002708  0.374684  0.663872
# 1    上海  2011  0.578831  89.30  0.001251  0.002484  0.389267  0.587136
# 2    上海  2012  0.599998  89.30  0.001135  0.002268  0.358528  0.565244
# 3    上海  2013  0.622396  89.60  0.000999  0.002152  0.357666  0.525226
# 4    上海  2014  0.648187  89.30  0.000798  0.002066  0.315476  0.470482
# ..   ..   ...       ...    ...       ...       ...       ...       ...
# 116  云南  2016  0.462380  44.64  0.003539  0.005322  0.498231  0.721321
# 117  云南  2017  0.473832  46.29  0.002325  0.005373  0.473231  0.675323
# 118  云南  2018  0.471157  47.44  0.001670  0.005465  0.456211  0.648170
# 119  云南  2019  0.526381  48.67  0.001015  0.005778  0.442559  0.523516
# 120  云南  2020  0.515274  50.05  0.000720  0.006009  0.428907  0.398862
#
#      清洁能源消费占比     碳排放强度    烟粉尘排放量
# 0    0.195711  0.956709  0.000502
# 1    0.211497  0.888757  0.000468
# 2    0.221758  0.838356  0.000434
# 3    0.238240  0.841505  0.000375
# 4    0.238687  0.664433  0.000601
# ..        ...       ...       ...
# 116  0.171180  1.241006  0.001665
# 117  0.180867  1.199038  0.001356
# 118  0.192967  1.149157  0.001802
# 119  0.201188  0.741108  0.002248
# 120  0.209410  0.838906  0.001206
#
# [121 rows x 11 columns]

# %% [markdown]
# 能源结构多重共线性排除

# %%
X = data[['产业结构', '城镇化率', '二氧化硫排放强度', '劳动力升级', '煤炭消费占比', '能源效率', '清洁能源消费占比', '碳排放强度', '烟粉尘排放量']]
# 增加截距变量
X = sm.add_constant(X)

# 计算VIF
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#     feature         VIF
# 0     const  555.206094
# 1      产业结构    4.471609
# 2      城镇化率    5.493022
# 3  二氧化硫排放强度   19.253702
# 4     劳动力升级    2.635803
# 5    煤炭消费占比   10.707657
# 6      能源效率   16.794319
# 7  清洁能源消费占比    2.178080
# 8     碳排放强度   37.729670
# 9    烟粉尘排放量    8.512115

# %%
X = data[['产业结构', '城镇化率', '二氧化硫排放强度', '劳动力升级', '煤炭消费占比', '能源效率', '清洁能源消费占比', '烟粉尘排放量']]
# 增加截距变量
X = sm.add_constant(X)

# 计算VIF
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#     feature         VIF
# 0     const  398.701981
# 1      产业结构    3.184093
# 2      城镇化率    5.416911
# 3  二氧化硫排放强度   12.922525
# 4     劳动力升级    2.603523
# 5    煤炭消费占比    2.325492
# 6      能源效率   10.015898
# 7  清洁能源消费占比    2.156715
# 8    烟粉尘排放量    8.059530

# %%
X = data[['产业结构', '城镇化率', '劳动力升级', '煤炭消费占比', '能源效率', '清洁能源消费占比', '烟粉尘排放量']]
# 增加截距变量
X = sm.add_constant(X)

# 计算VIF
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#     feature         VIF
# 0     const  256.491958
# 1      产业结构    2.812506
# 2      城镇化率    5.390582
# 3     劳动力升级    2.593409
# 4    煤炭消费占比    2.246569
# 5      能源效率    3.298860
# 6  清洁能源消费占比    1.945856
# 7    烟粉尘排放量    5.780411

# %%
DATA = pd.read_excel("绿色金融.xlsx")
DATA
# Out:
#       省份    年份  A股上市环保企业新增银行贷款占比  高能耗行业利息支出占比  上市环保企业A股市值占比  上市高能耗企业A股市值占比  \
# 0    上海市  2010          0.000000        0.507      0.000000       0.000321
# 1    上海市  2011          0.000002        0.387      0.000073       0.000471
# 2    上海市  2012          0.000016        0.368      0.000131       0.000431
# 3    上海市  2013          0.000053        0.363      0.000173       0.000430
# 4    上海市  2014          0.000034        0.306      0.000149       0.000449
# ..   ...   ...               ...          ...           ...            ...
# 116  云南省  2016          0.000162        0.815      0.000596       0.000126
# 117  云南省  2017          0.008611        0.794      0.000494       0.000077
# 118  云南省  2018          0.007977        0.810      0.000473       0.000073
# 119  云南省  2019          0.006722        0.793      0.000388       0.000063
# 120  云南省  2020          0.005776        0.798      0.000309       0.000049
#
#      规模环境污染保险  环境污染保险赔偿比例  环境污染治理投资占比  财政环保支出占比
# 0    0.012446      0.4942    0.007480  0.031452
# 1    0.023078      0.4820    0.007236  0.024216
# 2    0.016835      0.8995    0.006294  0.034655
# 3    0.017207      0.5869    0.008085  0.021176
# 4    0.019202      0.6078    0.009893  0.030778
# ..        ...         ...         ...       ...
# 116  0.052244      0.6725    0.008907  0.036213
# 117  0.046015      0.6754    0.007714  0.035292
# 118  0.043073      0.9340    0.007447  0.023391
# 119  0.055415      0.6498    0.011784  0.026725
# 120  0.059740      0.8103    0.006434  0.027956
#
# [121 rows x 10 columns]

# %%
DATA.columns
# Out:
# Index(['省份', '年份', 'A股上市环保企业新增银行贷款占比', '高能耗行业利息支出占比', '上市环保企业A股市值占比',
#        '上市高能耗企业A股市值占比', '规模环境污染保险', '环境污染保险赔偿比例', '环境污染治理投资占比', '财政环保支出占比'],
#       dtype='object')

# %%
X = DATA[['A股上市环保企业新增银行贷款占比', '高能耗行业利息支出占比', '上市环保企业A股市值占比','上市高能耗企业A股市值占比', '规模环境污染保险', '环境污染保险赔偿比例', '环境污染治理投资占比', '财政环保支出占比']]
X = sm.add_constant(X)

# 计算VIF
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
#             feature        VIF
# 0             const  47.966159
# 1  A股上市环保企业新增银行贷款占比   1.337528
# 2       高能耗行业利息支出占比   1.318441
# 3      上市环保企业A股市值占比   1.272484
# 4     上市高能耗企业A股市值占比   1.315227
# 5          规模环境污染保险   1.465922
# 6        环境污染保险赔偿比例   1.105857
# 7        环境污染治理投资占比   1.285154
# 8          财政环保支出占比   1.041789

# %%
Data = pd.read_excel("中介效应指标.xlsx")
Data
# Out:
#     province  year        GF        ES        TP        ep         es  \
# 0        上海市  2010  0.037657  0.305431  0.140690  4.711076  10.395059
# 1        上海市  2011  0.047329  0.312276  0.161507  4.679307  10.428088
# 2        上海市  2012  0.053396  0.320669  0.186831  4.551200  10.406158
# 3        上海市  2013  0.051407  0.330788  0.205493  4.569458  10.409756
# 4        上海市  2014  0.057363  0.336462  0.228873  4.563488  10.419223
# ..       ...   ...       ...       ...       ...       ...        ...
# 116      云南省  2016  0.041963  0.148090  0.023189  4.564264   8.863596
# 117      云南省  2017  0.244479  0.160697  0.027643  4.663989   8.875112
# 118      云南省  2018  0.226437  0.169687  0.029142  4.647910   8.877840
# 119      云南省  2019  0.198316  0.185735  0.029550  4.594951   9.061889
# 120      云南省  2020  0.173882  0.194335  0.029168  4.577885   9.106286
#
#           edp        er
# 0    1.454977  0.001355
# 1    1.472226  0.000829
# 2    1.365570  0.001513
# 3    1.252564  0.000671
# 4    1.215647  0.002198
# ..        ...       ...
# 116  0.089393  0.003107
# 117  0.096918  0.001371
# 118  0.110498  0.002009
# 119  0.100082  0.002210
# 120  0.110066  0.002551
#
# [121 rows x 9 columns]

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Assuming your data is stored in a DataFrame called 'df'

# Select the independent variables for VIF calculation
independent_vars = ['GF', 'ES', 'TP', 'ep', 'es', 'edp', 'er']

# Add a constant term to the data
X = add_constant(Data[independent_vars])

# Create a DataFrame to store the VIF results
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Print the VIF results
print(vif_data)
# Out:
#   Variable           VIF
# 0    const  12056.932536
# 1       GF      1.112112
# 2       ES      5.129266
# 3       TP      2.374731
# 4       ep      1.168289
# 5       es     11.687578
# 6      edp      8.434018
# 7       er      1.294065

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Assuming your data is stored in a DataFrame called 'df'

# Select the independent variables for VIF calculation
independent_vars = ['GF', 'TP', 'ep', 'es', 'edp', 'er']

# Add a constant term to the data
X = add_constant(Data[independent_vars])

# Create a DataFrame to store the VIF results
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Print the VIF results
print(vif_data)
# Out:
#   Variable           VIF
# 0    const  11883.278184
# 1       GF      1.095628
# 2       TP      2.063167
# 3       ep      1.075467
# 4       es     10.653844
# 5      edp      8.192520
# 6       er      1.072115

# %%
import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Assuming your data is stored in a DataFrame called 'df'

# Select the independent variables for VIF calculation
independent_vars = ['GF', 'ES', 'TP', 'ep', 'edp', 'er']

# Add a constant term to the data
X = add_constant(Data[independent_vars])

# Create a DataFrame to store the VIF results
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Print the VIF results
print(vif_data)
# Out:
#   Variable          VIF
# 0    const  8738.464686
# 1       GF     1.072078
# 2       ES     4.675596
# 3       TP     1.902330
# 4       ep     1.167879
# 5      edp     2.774783
# 6       er     1.292749

# %%
DATA = pd.read_excel("中介效应指标x5(1).xlsx")

import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Assuming your data is stored in a DataFrame called 'df'

# Select the independent variables for VIF calculation
independent_vars = ['GF', 'ES', 'TP', 'ep', 'es', 'edp', 'er']

# Add a constant term to the data
X = add_constant(Data[independent_vars])

# Create a DataFrame to store the VIF results
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Print the VIF results
print(vif_data)
# Out:
#   Variable           VIF
# 0    const  12056.932536
# 1       GF      1.112112
# 2       ES      5.129266
# 3       TP      2.374731
# 4       ep      1.168289
# 5       es     11.687578
# 6      edp      8.434018
# 7       er      1.294065

# %%
DATA = pd.read_excel("中介效应指标x5(1).xlsx")

import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Assuming your data is stored in a DataFrame called 'df'

# Select the independent variables for VIF calculation
independent_vars = ['GF', 'ES', 'TP', 'ep', 'edp', 'er']

# Add a constant term to the data
X = add_constant(Data[independent_vars])

# Create a DataFrame to store the VIF results
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Print the VIF results
print(vif_data)
# Out:
#   Variable          VIF
# 0    const  8738.464686
# 1       GF     1.072078
# 2       ES     4.675596
# 3       TP     1.902330
# 4       ep     1.167879
# 5      edp     2.774783
# 6       er     1.292749

# %% [markdown]
# 控制变量

# %%
DATA = pd.read_excel("中介效应指标x5(1).xlsx")

import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Assuming your data is stored in a DataFrame called 'df'

# Select the independent variables for VIF calculation
independent_vars = ['GF', 'TP', 'ep', 'es', 'edp', 'er']

# Add a constant term to the data
X = add_constant(DATA[independent_vars])

# Create a DataFrame to store the VIF results
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Print the VIF results
print(vif_data)
# Out:
#   Variable           VIF
# 0    const  11887.596370
# 1       GF      1.095628
# 2       TP      2.068779
# 3       ep      1.075459
# 4       es     10.674756
# 5      edp      8.200360
# 6       er      1.072125

# %%
DATA = pd.read_excel("中介效应指标x5(1).xlsx")

import pandas as pd
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# Assuming your data is stored in a DataFrame called 'df'

# Select the independent variables for VIF calculation
independent_vars = ['GF', 'ep', 'es', 'edp', 'er']

# Add a constant term to the data
X = add_constant(DATA[independent_vars])

# Create a DataFrame to store the VIF results
vif_data = pd.DataFrame()
vif_data["Variable"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Print the VIF results
print(vif_data)
# Out:
#   Variable           VIF
# 0    const  11281.654548
# 1       GF      1.085682
# 2       ep      1.064757
# 3       es      6.528964
# 4      edp      6.426077
# 5       er      1.065789

# %%
你自己决定要不要被解释变量
